# %% [markdown]
# 1 - Visualizando os dados

# %%
import pandas as pd
import matplotlib as plt

dados_educacao = pd.read_excel("Dados-limpos.xlsx")
display(dados_educacao)
# Out:
#       Territorialidades  \
# 0                  Acre
# 1               Alagoas
# 2                 Amapá
# 3              Amazonas
# 4                 Bahia
# 5                 Ceará
# 6      Distrito Federal
# 7        Espírito Santo
# 8                 Goiás
# 9              Maranhão
# 10   Mato Grosso do Sul
# 11          Mato Grosso
# 12         Minas Gerais
# 13              Paraíba
# 14               Paraná
# 15                 Pará
# 16           Pernambuco
# 17                Piauí
# 18       Rio de Janeiro
# 19  Rio Grande do Norte
# 20    Rio Grande do Sul
# 21             Rondonia
# 22              Roraima
# 23       Santa Catarina
# 24            São Paulo
# 25              Sergipe
# 26            Tocantins
#
#     % de matri­culas da rede publica no ensino fundamental 2017  \
# 0                                               95.65
# 1                                               83.04
# 2                                               90.87
# ...

# %% [markdown]
# 2 - Analises do % de matri­culas da rede publica no ensino fundamental 2017

# %%
import matplotlib.pyplot as plt

# Datos
territorios = [ 'Acre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará', 
                     'Distrito Federal', 'Espírito Santo', 'Goiás', 'Maranhão', 
                     'Mato Grosso do Sul', 'Mato Grosso', 'Minas Gerais', 'Paraíba', 
                     'Paraná', 'Pará', 'Pernambuco', 'Piauí', 'Rio de Janeiro', 
                     'Rio Grande do Norte', 'Rio Grande do Sul', 'Rondonia', 
                     'Roraima', 'Santa Catarina', 'São Paulo', 'Sergipe', 'Tocantins']
porcentagem = [ 95.65, 83.04, 90.87, 92.86, 83.99, 79.47, 73.62, 87.49, 81.09, 
               89.85, 88.49, 87.86, 87.86, 79.74, 85.47, 91.28, 76.99, 86.42, 69.57, 
               79.26, 87.38, 92.30, 91.85, 87.44, 79.72, 77.60, 91.06]

plt.figure(figsize=(10, 8))
plt.barh(territorios, porcentagem, color='green')
plt.xlabel('% de Matrículas da Rede Pública')
plt.title('% de Matrículas da Rede Pública no Ensino Fundamental (2017)')
plt.show()
